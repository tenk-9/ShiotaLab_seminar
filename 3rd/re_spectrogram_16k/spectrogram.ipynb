# %% [markdown]
# # スペクトログラムの表示

# %%
#まず必要なライブラリをインストール
# !pip install librosa
# !pip install numpy
# Out:
# Requirement already satisfied: librosa in /home/tenk9/anaconda3/lib/python3.10/site-packages (0.10.1)
# Requirement already satisfied: audioread>=2.1.9 in /home/tenk9/anaconda3/lib/python3.10/site-packages (from librosa) (3.0.1)
# Requirement already satisfied: numpy!=1.22.0,!=1.22.1,!=1.22.2,>=1.20.3 in /home/tenk9/anaconda3/lib/python3.10/site-packages (from librosa) (1.23.5)
# Requirement already satisfied: scipy>=1.2.0 in /home/tenk9/.local/lib/python3.10/site-packages (from librosa) (1.10.1)
# Requirement already satisfied: scikit-learn>=0.20.0 in /home/tenk9/.local/lib/python3.10/site-packages (from librosa) (1.2.2)
# Requirement already satisfied: joblib>=0.14 in /home/tenk9/.local/lib/python3.10/site-packages (from librosa) (1.2.0)
# Requirement already satisfied: decorator>=4.3.0 in /home/tenk9/.local/lib/python3.10/site-packages (from librosa) (5.1.1)
# Requirement already satisfied: numba>=0.51.0 in /home/tenk9/anaconda3/lib/python3.10/site-packages (from librosa) (0.56.4)
# Requirement already satisfied: soundfile>=0.12.1 in /home/tenk9/anaconda3/lib/python3.10/site-packages (from librosa) (0.12.1)
# Requirement already satisfied: pooch>=1.0 in /home/tenk9/anaconda3/lib/python3.10/site-packages (from librosa) (1.4.0)
# Requirement already satisfied: soxr>=0.3.2 in /home/tenk9/anaconda3/lib/python3.10/site-packages (from librosa) (0.3.7)
# Requirement already satisfied: typing-extensions>=4.1.1 in /home/tenk9/.local/lib/python3.10/site-packages (from librosa) (4.6.3)
# Requirement already satisfied: lazy-loader>=0.1 in /home/tenk9/anaconda3/lib/python3.10/site-packages (from librosa) (0.3)
# Requirement already satisfied: msgpack>=1.0 in /home/tenk9/anaconda3/lib/python3.10/site-packages (from librosa) (1.0.3)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /home/tenk9/anaconda3/lib/python3.10/site-packages (from numba>=0.51.0->librosa) (0.39.1)
# Requirement already satisfied: setuptools in /home/tenk9/anaconda3/lib/python3.10/site-packages (from numba>=0.51.0->librosa) (65.6.3)
# Requirement already satisfied: requests in /home/tenk9/.local/lib/python3.10/site-packages (from pooch>=1.0->librosa) (2.30.0)
# Requirement already satisfied: packaging in /home/tenk9/.local/lib/python3.10/site-packages (from pooch>=1.0->librosa) (23.0)
# Requirement already satisfied: appdirs in /home/tenk9/anaconda3/lib/python3.10/site-packages (from pooch>=1.0->librosa) (1.4.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/tenk9/.local/lib/python3.10/site-packages (from scikit-learn>=0.20.0->librosa) (3.1.0)
# Requirement already satisfied: cffi>=1.0 in /home/tenk9/.local/lib/python3.10/site-packages (from soundfile>=0.12.1->librosa) (1.15.1)
# Requirement already satisfied: pycparser in /home/tenk9/.local/lib/python3.10/site-packages (from cffi>=1.0->soundfile>=0.12.1->librosa) (2.21)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/tenk9/.local/lib/python3.10/site-packages (from requests->pooch>=1.0->librosa) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/tenk9/anaconda3/lib/python3.10/site-packages (from requests->pooch>=1.0->librosa) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/tenk9/anaconda3/lib/python3.10/site-packages (from requests->pooch>=1.0->librosa) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in /home/tenk9/.local/lib/python3.10/site-packages (from requests->pooch>=1.0->librosa) (2023.5.7)
#
# [notice] A new release of pip is available: 23.1.2 -> 23.3.1
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: numpy in /home/tenk9/anaconda3/lib/python3.10/site-packages (1.23.5)
#
# [notice] A new release of pip is available: 23.1.2 -> 23.3.1
# [notice] To update, run: pip install --upgrade pip

# %%
import librosa
import numpy as np
import os

DIR = os.getcwd()
filename = f"{DIR}/voice_16k.wav" #任意のファイル名に変更してください。

#wavの読み込み
wav, sr = librosa.load(filename, sr=16000) #srはサンプリングレートなので、必要に応じて変更してください。
print("sr: ",sr)
# Out:
# sr:  16000

# %%
from matplotlib import pyplot as plt

#FFT点数
n_fft = 2048
#窓長
win_length = [64, 128, 256, 512, 1024, 2048]
#シフト量
hop_length = [wl//4 for wl in win_length]

## 比較plot用subplot
fig, ax = plt.subplots(
    figsize=(15,15),
    nrows=3,
    ncols=2,
)

for i in range(len(win_length)):
    tar_ax = ax[i//2][i%2]
    #短時間フーリエ変換
    D = librosa.stft(wav, n_fft=n_fft, win_length=win_length[i], hop_length=hop_length[i])
    #Dは複素数なので絶対値をとって振幅を得る
    S = np.abs(D)
    #デシベルに変換
    db = librosa.amplitude_to_db(S, ref=np.max)
    #スペクトログラム表示
    librosa.display.specshow(db, sr=sr, x_axis='time', y_axis='linear', ax=tar_ax)
    tar_ax.set_title(f"win_length={win_length[i]}")

plt.savefig(f"{DIR}/windowFunc_16k.png", dpi=600)
